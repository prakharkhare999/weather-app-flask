# %%
import pandas as pd

df=pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# see the row and columnj
df.shape
# Out:
# (88883, 85)

# %%
# info about df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
# weq have aprox 85 column but in jupyter ishow shows only fews
# so use this for see 
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df=pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
#head 
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail()

# %% [markdown]
# # Data frame

# %% [markdown]
# # type -1

# %%
# this way we can see only one person data
people={"first":"Corey",
        "last":"Schafer",
        "email":"CoreyMschafer@gmail.com"
}

# %%
# this way we can see only one person data
people={"first":["Corey"],
        "last":["Schafer"],
        "email":["CoreyMschafer@gmail.com"]
}

# %%
# this way we can see only one person data
people={"first":["Corey","jane","john"],
        "last":["Schafer","Doe","Doe"],
        "email":["CoreyMschafer@gmail.com","JaneDoe@gmail.com","JohnDoe@gmail.com"]
}

# %%
# this is returning a values of key
people['email']
# Out:
# ['CoreyMschafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']

# %%
import pandas as pd
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   jane      Doe        JaneDoe@gmail.com
# 2   john      Doe        JohnDoe@gmail.com

# %%
# This is returning a series (we prefre first one)
df['email']
# or (both working same)
# df.email
# Out:
# 0    CoreyMschafer@gmail.com
# 1          JaneDoe@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
# can we check also
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
# when we need two column
df[['last','email']]
# its not a series its return a dataframe also
# Out:
#       last                    email
# 0  Schafer  CoreyMschafer@gmail.com
# 1      Doe        JaneDoe@gmail.com
# 2      Doe        JohnDoe@gmail.com

# %%
# how to see all columns
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# # loc and iloc

# %% [markdown]
# # iloc

# %%
# interger index

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   jane      Doe        JaneDoe@gmail.com
# 2   john      Doe        JohnDoe@gmail.com

# %%
# when you access the row its always set the column to the index
df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMschafer@gmail.com
# Name: 0, dtype: object

# %%
# use can show multiple row also
df.iloc[[0,1]]
# after selecting multiple row , column isnot converted into columns
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   jane      Doe        JaneDoe@gmail.com

# %%
# , is going to seprated then row and index when accesing
df.iloc[[0,1],2]
# Out:
# 0    CoreyMschafer@gmail.com
# 1          JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# # loc - . sum similiary like iloc but differnet

# %%
# same as iloc
df.loc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMschafer@gmail.com
# Name: 0, dtype: object

# %%
# same as iloc
df.loc[[0,1]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   jane      Doe        JaneDoe@gmail.com

# %% [markdown]
# # but in this use use labels also

# %%
df.loc[[0,1],'email']
# Out:
# 0    CoreyMschafer@gmail.com
# 1          JaneDoe@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['email','last']]
# Out:
#                      email     last
# 0  CoreyMschafer@gmail.com  Schafer
# 1        JaneDoe@gmail.com      Doe

# %%
import pandas as pd

df=pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# counts the valuas
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
# first row and hoby column result
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
# o,1,2 row and hoby column
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
# o,1,2 row and hoby column by slicing the row when we slice the ror do not need to insert in the list liek upper
df.loc[0:2,'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %% [markdown]
# # in lables slicing is exclusive

# %%
df.loc[0:2,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# # Indexes

# %% [markdown]
# # set index

# %%
demo1={"first":["Corey","jane","john"],
        "last":["Schafer","Doe","Doe"],
        "email":["CoreyMschafer@gmail.com","JaneDoe@gmail.com","JohnDoe@gmail.com"]
}
demo=pd.DataFrame(demo1)

# %%
demo
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   jane      Doe        JaneDoe@gmail.com
# 2   john      Doe        JohnDoe@gmail.com

# %%
demo.set_index('email')
# Out:
#                          first     last
# email
# CoreyMschafer@gmail.com  Corey  Schafer
# JaneDoe@gmail.com         jane      Doe
# JohnDoe@gmail.com         john      Doe

# %%
demo
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMschafer@gmail.com
# 1   jane      Doe        JaneDoe@gmail.com
# 2   john      Doe        JohnDoe@gmail.com

# %% [markdown]
# # what this is not changing in the real data

# %% [markdown]
# # because the reason is the new attribute inplace=True

# %%
demo.set_index('email',inplace=True)

# %%
demo
# Out:
#                          first     last
# email
# CoreyMschafer@gmail.com  Corey  Schafer
# JaneDoe@gmail.com         jane      Doe
# JohnDoe@gmail.com         john      Doe

# %%
demo.index
# Out:
# Index(['CoreyMschafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com'], dtype='object', name='email')

# %%
demo.loc['CoreyMschafer@gmail.com']
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMschafer@gmail.com, dtype: object

# %%
demo.loc['CoreyMschafer@gmail.com','last']
# Out:
# 'Schafer'

# %%
demo.loc[0]
# becasue this is not default integer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 demo.loc[0]
#       2 # becasue this is not default integer
#
# ...

# %%
demo.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMschafer@gmail.com, dtype: object

# %%
# if we want to reset the index there
demo.reset_index(inplace=True)

# %%
demo.head()
# Out:
#                      email  first     last
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2        JohnDoe@gmail.com   john      Doe

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# how to set column name for a index



df=pd.read_csv('data/survey_results_public.csv',index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.loc[1]
# Out:
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                 Not employed, and not looking for work
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 84, dtype: object

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df=pd.read_csv('data/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %% [markdown]
# # we can esay access the value

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %% [markdown]
# # sort_index

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %% [markdown]
# # Filtering

# %%
# we use our demo datafraje here

# %%
demo
# Out:
#                      email  first     last
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2        JohnDoe@gmail.com   john      Doe

# %%
demo['last']=='Doe'

# its shows the row matches our condition or not
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %% [markdown]
# # so we use some varibale for filtering but we will not use the filter keyword becausr its a keyword in python

# %%
filt=(demo['last']=='Doe')
# its hold the seies shown in upper code

# %%
# use this variable as a filter
demo[filt]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  jane  Doe
# 2  JohnDoe@gmail.com  john  Doe

# %%
# we can use directly also
demo[(demo['last']=='Doe')]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  jane  Doe
# 2  JohnDoe@gmail.com  john  Doe

# %%
# same result=> in loc we access data by label but we cn also access by boolean data series
demo.loc[filt,'email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
filt=(demo['last']=='Doe') & (demo['first']=='john')

# %%
demo[filt]
# Out:
#                email first last
# 2  JohnDoe@gmail.com  john  Doe

# %%
demo.loc[filt,'email']
# Out:
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# # for or  => |

# %%
# if u add tilda starting in the filt its give which does not match
demo.loc[~filt,'email']
# Out:
# 0    CoreyMschafer@gmail.com
# 1          JaneDoe@gmail.com
# Name: email, dtype: object

# %%
# do some in our df
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
fltr=(df['Age']>19)
df.loc[fltr,['WelcomeChange','Dependents','Hobbyist']]
# Out:
#                                       WelcomeChange Dependents Hobbyist
# Respondent
# 3           Just as welcome now as I felt last year        Yes      Yes
# 4           Just as welcome now as I felt last year         No       No
# 5           Just as welcome now as I felt last year         No      Yes
# 6           Just as welcome now as I felt last year         No      Yes
# 7             A lot more welcome now than last year        Yes       No
# ...                                             ...        ...      ...
# 86638       Just as welcome now as I felt last year        Yes      Yes
# 87352       Just as welcome now as I felt last year         No      Yes
# 87386       Just as welcome now as I felt last year         No      Yes
# 87739       Just as welcome now as I felt last year         No      Yes
# 88212                                           NaN         No       No
#
# [74324 rows x 3 columns]

# %%
countries=['United States','India','United Kingdom','Germany','Canada']
filt=df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %% [markdown]
# # filter string

# %%
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
filt
# only for fun
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %% [markdown]
# # Updating the data

# %%
demo.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
# update like this also
demo.columns=['first_name','last_name','email']
demo
# Out:
#                 first_name last_name    email
# 0  CoreyMschafer@gmail.com     Corey  Schafer
# 1        JaneDoe@gmail.com      jane      Doe
# 2        JohnDoe@gmail.com      john      Doe

# %%
# How to upper case the column name
demo.columns=[x.upper()  for x in demo.columns]
demo
# Out:
#                 FIRST_NAME LAST_NAME    EMAIL
# 0  CoreyMschafer@gmail.com     Corey  Schafer
# 1        JaneDoe@gmail.com      jane      Doe
# 2        JohnDoe@gmail.com      john      Doe

# %%
# how to replace space as underscore
demo.columns=demo.columns.str.replace('_',' ')
demo
# Out:
#                 FIRST NAME LAST NAME    EMAIL
# 0  CoreyMschafer@gmail.com     Corey  Schafer
# 1        JaneDoe@gmail.com      jane      Doe
# 2        JohnDoe@gmail.com      john      Doe

# %%
# How to lower case the column name
demo.columns=[x.lower()  for x in demo.columns]
demo
# Out:
#                 first name last name    email
# 0  CoreyMschafer@gmail.com     Corey  Schafer
# 1        JaneDoe@gmail.com      jane      Doe
# 2        JohnDoe@gmail.com      john      Doe

# %%
# how to replace underscore with space
demo.columns=demo.columns.str.replace(' ','_')
demo
# Out:
#                 first_name last_name    email
# 0  CoreyMschafer@gmail.com     Corey  Schafer
# 1        JaneDoe@gmail.com      jane      Doe
# 2        JohnDoe@gmail.com      john      Doe

# %% [markdown]
# # in rename we have to use inplace

# %%
demo.rename(columns={'first_name':'first','last_name':'last'},inplace=True)
demo
# Out:
#                      first   last    email
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2        JohnDoe@gmail.com   john      Doe

# %% [markdown]
# # rename because i rename wrong in uppers code mistakely

# %%
demo.rename(columns={'first':'email','email':'first'},inplace=True)

# %% [markdown]
# # Changing value in the dataframe
# like  row data

# %%
demo
# Out:
#                      email   last    first
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2      JohnSmith@gmail.com  smith     John

# %%
# changing data in row
demo.loc[2] = ["JohnSmith@gmail.com","smith",'John']

# %%
demo
# Out:
#                      email   last    first
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2      JohnSmith@gmail.com  smith     John

# %%
# change the last ans email 
demo.loc[2,['last','email']]=['khare','khare@gmail.com']

# %%
demo
# Out:
#                      email   last    first
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2          khare@gmail.com  khare     John

# %%
demo.loc[2,'first']='Prakhar'

# %%
demo
# Out:
#                      email   last    first
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2          khare@gmail.com  khare  Prakhar

# %% [markdown]
# # one alternative for single value is -> at

# %%
demo.at[2,'last']='kumar'

# %%
demo
# Out:
#                      email   last    first
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2          khare@gmail.com  kumar  Prakhar

# %%
# use of filter on this also
filt=(demo['email']=='khare@gmail.com')
demo.loc[filt,'last']='smith'

# %%
demo
# Out:
#                      email   last    first
# 0  CoreyMschafer@gmail.com  Corey  Schafer
# 1        JaneDoe@gmail.com   jane      Doe
# 2          khare@gmail.com  smith  Prakhar

# %%
# change multiple row at once
demo['email']=demo['email'].str.lower()

# %%
demo
# Out:
#                      email   last    first
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@gmail.com   jane      Doe
# 2          khare@gmail.com  smith  Prakhar

# %% [markdown]
# # we are going to use advanced methods
# apply
# map
# applymap
# replace

# %% [markdown]
# # apply on series

# %%
demo['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    15
# Name: email, dtype: int64

# %% [markdown]
# # use the normal function for updating

# %%
def update_email(email):
    return email.upper()

# %%
demo['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@GMAIL.COM
# 2            KHARE@GMAIL.COM
# Name: email, dtype: object

# %%
demo['email']=demo['email'].apply(update_email)
demo
# Out:
#                      email   last    first
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@GMAIL.COM   jane      Doe
# 2          KHARE@GMAIL.COM  smith  Prakhar

# %% [markdown]
# # But we want to write function in the apply function so we use lambda

# %%
demo['email']=demo['email'].apply(lambda x:x.upper())

# %%
demo
# Out:
#                      email   last    first
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@GMAIL.COM   jane      Doe
# 2          KHARE@GMAIL.COM  smith  Prakhar

# %% [markdown]
# # it is not applying on the data frame only apply on the series("column") when u try to apply its not apply on the every elements but apply on the column name and give result what ewe do not want
# demo.apply(len)

# %%
demo.apply(len)# its default axis=row
demo.apply(len,axis="columns")
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
 # we can check also this
len(demo['email'])
# Out:
# 3

# %%
# when u have numerical data u want to get smething minimum
demo.apply(pd.Series.min)
# Out:
# email    COREYMSCHAFER@GMAIL.COM
# last                       Corey
# first                        Doe
# dtype: object

# %%
# same result also we have by lambda
demo.apply(lambda x:x.min())
# Out:
# email    COREYMSCHAFER@GMAIL.COM
# last                       Corey
# first                        Doe
# dtype: object

# %% [markdown]
# # For every indivisual element we use applymap
# # Apply map always works on dataframes

# %%
# see
demo.applymap(len)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15816\3857125979.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   demo.applymap(len)
#    email  last  first
# 0     23     5      7
# 1     17     4      3
# 2     15     5      7

# %%
#demo.applymap(lambda x:x.lower)
demo.applymap(str.lower)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15816\3466981861.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   demo.applymap(str.lower)
#                      email   last    first
# 0  coreymschafer@gmail.com  corey  schafer
# 1        janedoe@gmail.com   jane      doe
# 2          khare@gmail.com  smith  prakhar

# %% [markdown]
# # map => map is only for series
# # substitue values

# %%
demo
# Out:
#                      email   last    first
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@GMAIL.COM   jane      Doe
# 2          KHARE@GMAIL.COM  smith  Prakhar

# %%
demo['first'].map({'Schafer':'Chris','Doe':'Mary'})




# map change what u set but set NaN which are not matched with condition
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %% [markdown]
# # Replace
#  it did not not change the not matched values

# %%
demo['first'].replace({'Doe':'Shobhit','Schafer':'Yash'})
# Out:
# 0       Yash
# 1    Shobhit
# 2    Prakhar
# Name: first, dtype: object

# %%
# it is not change in the real demo so see the next code
demo
# Out:
#                      email   last    first
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@GMAIL.COM   jane      Doe
# 2          KHARE@GMAIL.COM  smith  Prakhar

# %%
# we write like this
demo['first']=demo['first'].replace({'Doe':'Shobhit','Schafer':'Yash'})

# %%
demo
# Out:
#                      email   last    first
# 0  COREYMSCHAFER@GMAIL.COM  Corey     Yash
# 1        JANEDOE@GMAIL.COM   jane  Shobhit
# 2          KHARE@GMAIL.COM  smith  Prakhar

# %% [markdown]
# # Add/Remove Rows and Columns From DataFrames

# %%
# Add the Column
demo['first']+' '+demo['last']
# Out:
# 0       Yash Corey
# 1     Shobhit jane
# 2    Prakhar smith
# dtype: object

# %%
# but you want a new column in your data frame 
demo['full name']=demo['first']+' '+demo['last']

# %%
demo
# Out:
#                      email   last    first      full name
# 0  COREYMSCHAFER@GMAIL.COM  Corey     Yash     Yash Corey
# 1        JANEDOE@GMAIL.COM   jane  Shobhit   Shobhit jane
# 2          KHARE@GMAIL.COM  smith  Prakhar  Prakhar smith

# %% [markdown]
# # we want to drop the column

# %%
demo.drop(columns={'first','last'},inplace=True)

# %%
demo
# Out:
#                      email      full name
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane
# 2          KHARE@GMAIL.COM  Prakhar smith

# %%
demo['full name'].str.split(' ')
# Out:
# 0       [Yash, Corey]
# 1     [Shobhit, jane]
# 2    [Prakhar, smith]
# Name: full name, dtype: object

# %%
demo['full name'].str.split(' ',expand=True)
# Out:
#          0      1
# 0     Yash  Corey
# 1  Shobhit   jane
# 2  Prakhar  smith

# %%
demo[['first','last']]=demo['full name'].str.split(' ',expand=True)

# %%
demo
# Out:
#                      email      full name    first   last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash  Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit   jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar  smith

# %% [markdown]
# # adding the row

# %%
demo.append({'first':'Tony'})
# it upper line gives us the error because we have to use a attribute for inserting the data in a row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15816\239996163.py in ?()
# ----> 1 demo.append({'first':'Tony'})
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# # Why concat() Instead of append()?
# # .append() was inefficient and has been removed.
# # concat() is faster and preferred for adding multiple rows.
# # 🔹 Use .concat() for appending data in modern Pandas. 🚀

# %%
demo = pd.concat([demo, pd.DataFrame([{'first': 'Tony'}])], ignore_index=True)

# %%
demo
# Out:
#                      email      full name    first   last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash  Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit   jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar  smith
# 3                      NaN            NaN     Tony    NaN

# %% [markdown]
# # Add one data frame to other data frame

# %%
data = {
    'first': ['Tony', 'Steve'],
    'last': ['Stark', 'Rogers'],
    'email': ['tony@stark.com', 'steve@rogers.com']
}

demo2 = pd.DataFrame(data)

# %%
demo2
# Out:
#    first    last             email
# 0   Tony   Stark    tony@stark.com
# 1  Steve  Rogers  steve@rogers.com

# %% [markdown]
# # append is  not working iun new version so use concat

# %%
# Append df2 into df1
demo = pd.concat([demo, demo2], ignore_index=True)

# %%
demo
# Out:
#                      email      full name    first    last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 3                      NaN            NaN     Tony     NaN
# 4           tony@stark.com            NaN     Tony   Stark
# 5         steve@rogers.com            NaN    Steve  Rogers

# %% [markdown]
# # drop a row by index

# %%
demo.drop(index=3,inplace=True)

# %%
demo
# Out:
#                      email      full name    first    last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 5         steve@rogers.com            NaN    Steve  Rogers

# %%
# with condition
# demo.drop(index=demo[demo['last']=='jane'].index)

# also do like this
filt=demo['last']=='jane'
demo.drop(index=filt.index,inplace=True)
# Out:
#                      email      full name    first    last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 5         steve@rogers.com            NaN    Steve  Rogers

# %% [markdown]
# # Sorting

# %%
demo
# Out:
#                      email      full name    first    last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 5         steve@rogers.com            NaN    Steve  Rogers

# %%
demo.sort_values(by='last')
# Out:
#                      email      full name    first    last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey
# 5         steve@rogers.com            NaN    Steve  Rogers
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith

# %%
demo.sort_values(by='last',ascending=False)
# Out:
#                      email      full name    first    last
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 5         steve@rogers.com            NaN    Steve  Rogers
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey

# %%
# Pass also multiple values
demo.sort_values(by=['last','first'],ascending=False)
# Out:
#                      email      full name    first    last
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 5         steve@rogers.com            NaN    Steve  Rogers
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey

# %%
# when you want to customize the sorting manner for each column
demo.sort_values(by=['last','first'],ascending=[False,True])
# Out:
#                      email      full name    first    last
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 5         steve@rogers.com            NaN    Steve  Rogers
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey

# %% [markdown]
# # sort by index

# %%
demo.sort_index()
# Out:
#                      email      full name    first    last
# 0  COREYMSCHAFER@GMAIL.COM     Yash Corey     Yash   Corey
# 1        JANEDOE@GMAIL.COM   Shobhit jane  Shobhit    jane
# 2          KHARE@GMAIL.COM  Prakhar smith  Prakhar   smith
# 5         steve@rogers.com            NaN    Steve  Rogers

# %%
demo['last'].sort_values()
# Out:
# 0     Corey
# 5    Rogers
# 1      jane
# 2     smith
# Name: last, dtype: object

# %%
# multiple coloums
df[['Country','ConvertedComp']].head()
# Out:
#                            Country  ConvertedComp
# Respondent
# 1                   United Kingdom            NaN
# 2           Bosnia and Herzegovina            NaN
# 3                         Thailand         8820.0
# 4                    United States        61000.0
# 5                          Ukraine            NaN

# %%
df.sort_values(by=['Country','ConvertedComp'],ascending=[True,False],inplace=True)

# %% [markdown]
# # extra method nlargest

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# # Grouping and aggeration

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 63129                          I am a developer by profession      Yes
# 50499       I am not primarily a developer, but I write co...      Yes
# 39258                          I am a developer by profession      Yes
# 58450                          I am a developer by profession      Yes
# 7085                           I am a developer by profession      Yes
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# 50499       Less than once per year
# 39258       Less than once per year
# 58450                         Never
# 7085        Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 63129       OSS is, on average, of HIGHER quality than pro...
# 50499       OSS is, on average, of LOWER quality than prop...
# 39258       OSS is, on average, of LOWER quality than prop...
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 722            0.0
# 28638          0.0
# 6417           NaN
# 7353           NaN
# 12310          NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# np.float64(57287.0)

# %%
# lets try aggeragate function on the data frame directly
df.median()
# its showing error but in the notebook its  running properly and give every coloumn median values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[278], line 2
#       1 # lets try aggeragate function on the data frame directly
# ----> 2 df.median()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11706, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11698 @doc(make_doc("median", ndim=2))
#   11699 def median(
#   11700     self,
#    (...)
#   11704     **kwargs,
#   11705 ):
# > 11706     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707     if isinstance(result, Series):
#   11708         result = result.__finalize__(self, method="median")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
# ...

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# np.int64(55823)

# %%
df['Hobbyist']
# Out:
# Respondent
# 63129    Yes
# 50499    Yes
# 39258    Yes
# 58450    Yes
# 7085     Yes
#         ...
# 88062     No
# 88076     No
# 88601     No
# 88802     No
# 88816     No
# Name: Hobbyist, Length: 88883, dtype: object

# %%
# give the value in the column counts
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 63129    I don't use social media
# 50499                    WhatsApp
# 39258                    Facebook
# 58450                    Facebook
# 7085                    Instagram
#                    ...
# 88062                         NaN
# 88076                         NaN
# 88601                         NaN
# 88802                         NaN
# 88816                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
# in percentage

df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# North Korea                  1
# Papua New Guinea             1
# Saint Kitts and Nevis        1
# Tonga                        1
# Timor-Leste                  1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# # Groupby

# %%
df.groupby(['Country'])

# %%
country_grp=df.groupby(['Country'])

# %% [markdown]
# # the code is working like filter then we use filter for some condition

# %%
country_grp.get_group('India')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15816\421256909.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('India')
#                                                    MainBranch Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 16793                          I am a developer by profession      Yes
# 52561                          I am a developer by profession      Yes
# ...                                                       ...      ...
# 77339                                                     NaN      Yes
# 79795                                                     NaN      Yes
# ...

# %%
# we are talking about this filter
filt=df['Country']=='United States'
df.loc[filt].head(5)
# same like our upper code
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 58          Once a month or more often
# 102                              Never
# 166            Less than once per year
# 436            Less than once per year
# 452                              Never
#
#                                                    OpenSource  \
# Respondent
# 58          OSS is, on average, of LOWER quality than prop...
# 102         The quality of OSS and closed source software ...
# 166         The quality of OSS and closed source software ...
# 436         The quality of OSS and closed source software ...
# ...
